# %%
#Assignment 1 - P1

import numpy as np
m=int(input("Enter value M: "))
n=int(input("Enter value N: "))
a=int(input("Enter value A: "))
x = np.random.random((m,n))
print("First array:")
print(x)
y = np.random.random((n,a))
print("Second array:")
print(y)
# np.dot(x,y) 
# np.matmul(x,y)
# Out:
# Enter value M: 2
# Enter value N: 3
# Enter value A: 2
# First array:
# [[0.82670081 0.9465818  0.07138552]
#  [0.62193164 0.17052044 0.87696938]]
# Second array:
# [[0.79854342 0.65593571]
#  [0.37506741 0.88821599]
#  [0.95536128 0.11028097]]

# %%
import numpy as np
x = np.array(['Python', 'PHP', 'JS', 'Examples', 'html5', '5'], dtype=str)
print("\nOriginal Array:",x)
# Out:
# Original Array: ['Python' 'PHP' 'JS' 'Examples' 'html5' '5']

# %%
np.char.isdigit(x)
# Out:
# array([False, False, False, False, False,  True])

# %%
# np.char.islower(x) , np.char.isupper(x)

# %%
inp = input("Please enter the value separated by space")
X,Y = inp.split(" ")
X = int(X)
Y = int(Y)

lst1 = list(range(1,X*16,X))
lst2 = list(range(1,Y*16,Y))

np1=np.array(lst1)
np2=np.array(lst2)

np1=np1.reshape((4,4))
np2=np2.reshape((4,4))

np3 = (np1-np2)

np3 = np.ravel(np3)
print(np3)
# Out:
# Please enter the value separated by space1 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c30e4725ebe2> in <module>()
#      10 np2=np.array(lst2)
#      11
# ---> 12 np1=np1.reshape((4,4))
#      13 np2=np2.reshape((4,4))
#      14
#
# ValueError: cannot reshape array of size 15 into shape (4,4)

# %%
np1

# %%
np2

# %%
np1 - np2

# %%
X = np.random.randint(0,100,(3,3))
Y = np.random.randint(0,100,(3,3))
X - Y
# Out:
# array([[-40, -32, -55],
#        [-45,  69,  11],
#        [ 25, -20,  48]])

# %%
X
# Out:
# array([[ 9,  9, 44],
#        [18, 89, 39],
#        [92, 30, 53]])

# %%
Y
# Out:
# array([[49, 41, 99],
#        [63, 20, 28],
#        [67, 50,  5]])

# %%
x = int(input('enter step X '))
y = int(input('enter step Y '))
lst1 = []
lst2 = []
a = 1
while len(lst1) != 16:
  lst1 = list(range(1,a+x,x))
  a+=x

a = 1
while len(lst2) != 16:
  lst2 = list(range(1,a+y,y))
  a+=y

np1 = np.array(lst1)
np2 = np.array(lst2)
print(np1)
print(np2)
np3 = np1-np2
# Out:
# enter step X 7
# enter step Y 2.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-7c22e5cbd8a2> in <module>()
#       1 x = int(input('enter step X '))
# ----> 2 y = int(input('enter step Y '))
#       3 lst1 = []
#       4 lst2 = []
#       5 a = 1
#
# ValueError: invalid literal for int() with base 10: '2.'

# %% [markdown]
# # Assignment 2

# %%
# !wget https://www.dropbox.com/s/2hg67jin2n852mz/top50spotify.csv
# Out:
# --2022-05-26 11:43:16--  https://www.dropbox.com/s/2hg67jin2n852mz/top50spotify.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/2hg67jin2n852mz/top50spotify.csv [following]
# --2022-05-26 11:43:17--  https://www.dropbox.com/s/raw/2hg67jin2n852mz/top50spotify.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uceb21bb78665508247ee8a07ad9.dl.dropboxusercontent.com/cd/0/inline/Bl8Mydf61NPuepnwqKsGhkrCsNtPXBNw3z0X6HLs0uETnwkamtRcz_zUFG3eHQlgbwXsUTjyezPFt8UEYW5hRBxoWbVezwYWPD13yen62MbUHzejFjhgA11Eqq9fKVAkUW_ApN6owXDYLfvxic_cmObOKzLWgv73HS5IorzCfykY7w/file# [following]
# ...

# %%
import pandas as pd
top50=pd.read_csv('top50spotify.csv')

# %%
top50.head()
# Out:
#    SerialNo.                       Track.Name    Artist.Name           Genre  \
# 0          1                         Señorita   Shawn Mendes    canadian pop
# 1          2                            China       Anuel AA  reggaeton flow
# 2          3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3          4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4          5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
top50.drop(columns="SerialNo.",inplace=True)
top50.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %%
top50.to_csv("top50.csv")

# %%
top50.iloc[:10]
# Out:
#                           Track.Name    Artist.Name           Genre  \
# 0                           Señorita   Shawn Mendes    canadian pop
# 1                              China       Anuel AA  reggaeton flow
# 2      boyfriend (with Social House)  Ariana Grande       dance pop
# 3    Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4        Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
# 5  I Don't Care (with Justin Bieber)     Ed Sheeran             pop
# 6                             Ransom      Lil Tecca      trap music
# 7                  How Do You Sleep?      Sam Smith             pop
# 8              Old Town Road - Remix      Lil Nas X     country rap
# 9                            bad guy  Billie Eilish      electropop
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# ...

# %%
first_10 = top50.head(10)
first_10
# Out:
#                           Track.Name    Artist.Name           Genre  \
# 0                           Señorita   Shawn Mendes    canadian pop
# 1                              China       Anuel AA  reggaeton flow
# 2      boyfriend (with Social House)  Ariana Grande       dance pop
# 3    Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4        Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
# 5  I Don't Care (with Justin Bieber)     Ed Sheeran             pop
# 6                             Ransom      Lil Tecca      trap music
# 7                  How Do You Sleep?      Sam Smith             pop
# 8              Old Town Road - Remix      Lil Nas X     country rap
# 9                            bad guy  Billie Eilish      electropop
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# ...

# %%
first_10[['Energy','Length.']].mean()
# Out:
# Energy      65.1
# Length.    195.6
# dtype: float64

# %%
# take sum() , and divide by 10

# %%
top50.groupby("Genre")['Length.'].sum().sort_values(ascending=False)
# Out:
# Genre
# dance pop           1621
# pop                 1368
# latin               1126
# edm                  656
# reggaeton flow       611
# canadian hip hop     579
# panamanian pop       514
# reggaeton            427
# brostep              396
# electropop           389
# canadian pop         382
# dfw rap              333
# country rap          272
# australian pop       210
# atl hip hop          200
# boy band             181
# escape room          173
# big room             164
# r&b en espanol       162
# pop house            153
# trap music           131
# Name: Length., dtype: int64

# %%
top50.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
result = top50.groupby(['Genre','Artist.Name'])['Track.Name'].count()

# %%
result
# Out:
# Genre             Artist.Name
# atl hip hop       Young Thug          1
# australian pop    Tones and I         1
# big room          Martin Garrix       1
# boy band          Jonas Brothers      1
# brostep           Marshmello          2
# canadian hip hop  Ali Gatie           1
#                   Drake               1
#                   Y2K                 1
# canadian pop      Shawn Mendes        2
# country rap       Lil Nas X           2
# dance pop         Ariana Grande       2
#                   Chris Brown         1
#                   DJ Snake            1
#                   Katy Perry          1
#                   Lady Gaga           1
#                   Lauv                1
#                   Taylor Swift        1
# dfw rap           Post Malone         2
# edm               Kygo                1
#                   The Chainsmokers    2
# electropop        Billie Eilish       2
# escape room       Lizzo               1
# latin             Daddy Yankee        1
# ...

# %%
result.index
# Out:
# MultiIndex([(     'atl hip hop',       'Young Thug'),
#             (  'australian pop',      'Tones and I'),
#             (        'big room',    'Martin Garrix'),
#             (        'boy band',   'Jonas Brothers'),
#             (         'brostep',       'Marshmello'),
#             ('canadian hip hop',        'Ali Gatie'),
#             ('canadian hip hop',            'Drake'),
#             ('canadian hip hop',              'Y2K'),
#             (    'canadian pop',     'Shawn Mendes'),
#             (     'country rap',        'Lil Nas X'),
#             (       'dance pop',    'Ariana Grande'),
#             (       'dance pop',      'Chris Brown'),
#             (       'dance pop',         'DJ Snake'),
#             (       'dance pop',       'Katy Perry'),
#             (       'dance pop',        'Lady Gaga'),
#             (       'dance pop',             'Lauv'),
#             (       'dance pop',     'Taylor Swift'),
# ...

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
result.max()
# Out:
# 4

# %%
result
# Out:
# Genre             Artist.Name
# atl hip hop       Young Thug          1
# australian pop    Tones and I         1
# big room          Martin Garrix       1
# boy band          Jonas Brothers      1
# brostep           Marshmello          2
# canadian hip hop  Ali Gatie           1
#                   Drake               1
#                   Y2K                 1
# canadian pop      Shawn Mendes        2
# country rap       Lil Nas X           2
# dance pop         Ariana Grande       2
#                   Chris Brown         1
#                   DJ Snake            1
#                   Katy Perry          1
#                   Lady Gaga           1
#                   Lauv                1
#                   Taylor Swift        1
# dfw rap           Post Malone         2
# edm               Kygo                1
#                   The Chainsmokers    2
# electropop        Billie Eilish       2
# escape room       Lizzo               1
# latin             Daddy Yankee        1
# ...

# %%
result[result == result.max()]
# Out:
# Genre  Artist.Name
# pop    Ed Sheeran     4
# Name: Track.Name, dtype: int64

# %%
top50[top50['Artist.Name'] == 'Ed Sheeran']
# Out:
#                                        Track.Name Artist.Name Genre  \
# 3                 Beautiful People (feat. Khalid)  Ed Sheeran   pop
# 5               I Don't Care (with Justin Bieber)  Ed Sheeran   pop
# 37                 Antisocial (with Travis Scott)  Ed Sheeran   pop
# 49  Cross Me (feat. Chance the Rapper & PnB Rock)  Ed Sheeran   pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 3                 93      65            64              -8         8
# 5                102      68            80              -5         9
# 37               152      82            72              -5        36
# 49                95      79            75              -6         7
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 3         55      198              12            19          86
# 5         84      220               9             4          84
# 37        91      162              13             5          87
# ...

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
result
# Out:
# Genre             Artist.Name
# atl hip hop       Young Thug          1
# australian pop    Tones and I         1
# big room          Martin Garrix       1
# boy band          Jonas Brothers      1
# brostep           Marshmello          2
# canadian hip hop  Ali Gatie           1
#                   Drake               1
#                   Y2K                 1
# canadian pop      Shawn Mendes        2
# country rap       Lil Nas X           2
# dance pop         Ariana Grande       2
#                   Chris Brown         1
#                   DJ Snake            1
#                   Katy Perry          1
#                   Lady Gaga           1
#                   Lauv                1
#                   Taylor Swift        1
# dfw rap           Post Malone         2
# edm               Kygo                1
#                   The Chainsmokers    2
# electropop        Billie Eilish       2
# escape room       Lizzo               1
# latin             Daddy Yankee        1
# ...

# %%
result.reset_index() # convert series to DataFrame
# Out:
#                Genre       Artist.Name  Track.Name
# 0        atl hip hop        Young Thug           1
# 1     australian pop       Tones and I           1
# 2           big room     Martin Garrix           1
# 3           boy band    Jonas Brothers           1
# 4            brostep        Marshmello           2
# 5   canadian hip hop         Ali Gatie           1
# 6   canadian hip hop             Drake           1
# 7   canadian hip hop               Y2K           1
# 8       canadian pop      Shawn Mendes           2
# 9        country rap         Lil Nas X           2
# 10         dance pop     Ariana Grande           2
# 11         dance pop       Chris Brown           1
# 12         dance pop          DJ Snake           1
# 13         dance pop        Katy Perry           1
# 14         dance pop         Lady Gaga           1
# 15         dance pop              Lauv           1
# 16         dance pop      Taylor Swift           1
# ...

# %%
r1 = top50[top50['Artist.Name'] == 'Ed Sheeran']
r1[['Track.Name','Artist.Name']]
# Out:
#                                        Track.Name Artist.Name
# 3                 Beautiful People (feat. Khalid)  Ed Sheeran
# 5               I Don't Care (with Justin Bieber)  Ed Sheeran
# 37                 Antisocial (with Travis Scott)  Ed Sheeran
# 49  Cross Me (feat. Chance the Rapper & PnB Rock)  Ed Sheeran

# %%
tests={'English':{'Sam':60,'Jackson':74,'Ahree':85}, 
       'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61}, 
       'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76}, 
       'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95}, 
       'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87} }

# %%
series = pd.Series(tests)
series
# Out:
# English                  {'Sam': 60, 'Jackson': 74, 'Ahree': 85}
# History        {'Gloria': 83, 'Sam': 65, 'Isla': 78, 'Aron': ...
# Geography      {'Jackson': 92, 'Gloria': 95, 'Isla': 82, 'Aro...
# Mathematics    {'Sam': 99, 'Gloria': 74, 'Jackson': 89, 'Ahre...
# Science        {'Sam': 89, 'Aron': 82, 'Gray': 78, 'Isla': 93...
# dtype: object

# %%
df = series.apply(pd.Series)
df
# Out:
#               Sam  Jackson  Ahree  Gloria  Isla  Aron  Gray
# English      60.0     74.0   85.0     NaN   NaN   NaN   NaN
# History      65.0      NaN    NaN    83.0  78.0  72.0  61.0
# Geography     NaN     92.0   76.0    95.0  82.0  75.0   NaN
# Mathematics  99.0     89.0   85.0    74.0   NaN   NaN  95.0
# Science      89.0      NaN   87.0     NaN  93.0  82.0  78.0

# %%
df = df.fillna(0)
df
# Out:
#               Sam  Jackson  Ahree  Gloria  Isla  Aron  Gray
# English      60.0     74.0   85.0     0.0   0.0   0.0   0.0
# History      65.0      0.0    0.0    83.0  78.0  72.0  61.0
# Geography     0.0     92.0   76.0    95.0  82.0  75.0   0.0
# Mathematics  99.0     89.0   85.0    74.0   0.0   0.0  95.0
# Science      89.0      0.0   87.0     0.0  93.0  82.0  78.0

# %%
df_t = df.T
df_t
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        0.0         99.0     89.0
# Jackson     74.0      0.0       92.0         89.0      0.0
# Ahree       85.0      0.0       76.0         85.0     87.0
# Gloria       0.0     83.0       95.0         74.0      0.0
# Isla         0.0     78.0       82.0          0.0     93.0
# Aron         0.0     72.0       75.0          0.0     82.0
# Gray         0.0     61.0        0.0         95.0     78.0

# %%
df_t["Average"] = df.apply(np.mean)
df_t
# Out:
#          English  History  Geography  Mathematics  Science  Average
# Sam         60.0     65.0        0.0         99.0     89.0     62.6
# Jackson     74.0      0.0       92.0         89.0      0.0     51.0
# Ahree       85.0      0.0       76.0         85.0     87.0     66.6
# Gloria       0.0     83.0       95.0         74.0      0.0     50.4
# Isla         0.0     78.0       82.0          0.0     93.0     50.6
# Aron         0.0     72.0       75.0          0.0     82.0     45.8
# Gray         0.0     61.0        0.0         95.0     78.0     46.8

# %%
df_t.apply(np.max,axis=1)
# Out:
# Sam        99.0
# Jackson    92.0
# Ahree      87.0
# Gloria     95.0
# Isla       93.0
# Aron       82.0
# Gray       95.0
# dtype: float64

# %%
df_t["max"] = df.apply(np.max,axis=0)
df_t
# Out:
#          English  History  Geography  Mathematics  Science  Average   max
# Sam         60.0     65.0        0.0         99.0     89.0     62.6  99.0
# Jackson     74.0      0.0       92.0         89.0      0.0     51.0  92.0
# Ahree       85.0      0.0       76.0         85.0     87.0     66.6  87.0
# Gloria       0.0     83.0       95.0         74.0      0.0     50.4  95.0
# Isla         0.0     78.0       82.0          0.0     93.0     50.6  93.0
# Aron         0.0     72.0       75.0          0.0     82.0     45.8  82.0
# Gray         0.0     61.0        0.0         95.0     78.0     46.8  95.0

# %%
import numpy as np
import pandas as pd
series=pd.Series(np.arange(1,1001))
print(series[(series% 7==0) & (series%17==0)])
# Out:
# 118    119
# 237    238
# 356    357
# 475    476
# 594    595
# 713    714
# 832    833
# 951    952
# dtype: int64

# %%
series.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
119 % 7
# Out:
# 0

# %%
119%17
# Out:
# 0

# %%
# !wget https://www.dropbox.com/s/idnul34dfo5cnke/cereal.csv
# Out:
# --2022-05-26 11:51:08--  https://www.dropbox.com/s/idnul34dfo5cnke/cereal.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/idnul34dfo5cnke/cereal.csv [following]
# --2022-05-26 11:51:08--  https://www.dropbox.com/s/raw/idnul34dfo5cnke/cereal.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf0a5a888cde92185edc59d0520.dl.dropboxusercontent.com/cd/0/inline/BmCj-15HdRAAsrjCt_Yg9y9qLuOUzva82F6q6HWyur_WRinaJTAjitlfLAeOhysiAXVVl9NCbZ1ndJX1GV8rnDu9lUHk3j3OmQqvUabpTdTaPw_R2VElcsbyfvLUxE3P3cFb-nLrQzCWY_QPobxWa8RWUiCwt4hyT6HQTQhEcbjzAg/file# [following]
# ...

# %%
cereal = pd.read_csv('cereal.csv')
cereal.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6   280.0        25      3     1.0  0.33  68.402973
# 1    8.0       8   135.0         0      3     1.0  1.00  33.983679
# 2    7.0       5   320.0        25      3     1.0  0.33  59.425505
# 3    8.0       0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0       8     NaN        25      3     1.0  0.75  34.384843

# %%
rating = cereal.groupby('mfr')['rating'].mean()
rating
# Out:
# mfr
# A    54.850917
# G    34.485852
# K    44.038462
# N    67.968567
# P    41.705744
# Q    42.915990
# R    41.542997
# Name: rating, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(rating.index, rating.values)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.barh(rating.index, rating.values)
plt.xlim(0,100)
plt.show()

# %%
plt.style.use('seaborn')
plt.barh(rating.index, rating.values)
plt.xlim(0,100)
plt.show()
